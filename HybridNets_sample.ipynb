# %% [markdown]
# # Installing some prerequisites

# %%
# !apt-get install git unzip wget -y

# %% [markdown]
# # Clone the code from github repo

# %%
# %cd /content
# !git clone https://github.com/k3wj8h/HybridNets.git
# %cd /content/HybridNets

# %% [markdown]
# # Install requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Download and unzip the database
#
# The database is the 100K Image database of BDD100K with a simplified structure of labels

# %%
import os
if os.path.isfile('datasets.zip'):
    print('Database already downloaded')
else:
    # images and labels (datasets.zip)
    # !gdown 1sj0lC4IPluN8armUoK4iw6Wq5jIQ0l4F

    # unzip dataset
    print('Unzipping datasets...')
    # !unzip -q -o datasets.zip
    print('Unzipping done')

# if the files are not available please contact me at: bence.kataipal@gmail.com

# %% [markdown]
# ## Download pretrained checkpoint
# The checkpoint pretrained with 10 epochs

# %%
# %mkdir checkpoint
# %cd /content/HybridNets/checkpoint
# !gdown 1W1yb5B3dbCYOIobwqPW_pDSTxJlmgAcm
# %cd /content/HybridNets

# %% [markdown]
# # Train the model

# %% [markdown]
# At the end of the epochs the script automatically run a valudation on validation set, and save a checkpont to the checkpoint folder. The checkpoints contain the state of the model (current step and state of the optimizer) and losses of training and validation.

# %%
# !python train.py --num_epochs 15

# %% [markdown]
# Load one of the previous checkpoints to continue training

# %%
#!python train.py --num_epochs 15 --load_checkpoint './checkpoint/hybridnet_e10.ckpt'

# %% [markdown]
# # Validation

# %%
# !python val.py --checkpoint './checkpoint/hybridnet_e10.ckpt'

# %% [markdown]
# # Display the results

# %% [markdown]
# ## Losses

# %% [markdown]
# Generate plots about losses

# %%
# !python results.py --checkpoint './checkpoint/hybridnet_e10.ckpt'
# Out:
# ./sample_images/res_details_e10_sharey.png saved
# ./sample_images/res_details_e10.png saved
# ./sample_images/res_losses_e10.png saved

# %% [markdown]
# Show training and validation losses by epochs

# %%
from IPython.display import Image
Image(filename='./sample_images/res_losses_e10.png')

# %% [markdown]
# Show detailed training losses for each setps

# %%
Image(filename='./sample_images/res_details_e10_sharey.png')

# %% [markdown]
# ## Sample images

# %% [markdown]
# Run this cell to generate sample images

# %%
# !python samples.py --checkpoint './checkpoint/hybridnet_e10.ckpt' --num_of_images 20

# %% [markdown]
# With running the cell below, all images in *sample_images* folder will be downloaded.

# %%
# download sample images
from google.colab import files
import glob

for f in glob.glob('./sample_images/*.png'):
  files.download(f)
